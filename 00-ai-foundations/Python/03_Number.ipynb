# %%
print("Addition:", 15 + 7)
print("Subtraction:", 20 - 8)
print("Multiplication:", 6 * 4)
print("Division:", 10 / 2) # / always gives a float
print("Division:", 9 / 2) # / always gives a float
print("Floor division:", 9 // 2)
print("Remainder:", 9 % 2)
print("Power:", 4 ** 3)

print("Temperature:", 36.5)
print("Speed:", 88.75)

print("Complex number:", 2 + 3j)
print("Complex multiplication:", (2 + 3j) * (2 - 3j))
# Out:
# Addition: 22
# Subtraction: 12
# Multiplication: 24
# Division: 5.0
# Division: 4.5
# Floor division: 4
# Remainder: 1
# Power: 64
# Temperature: 36.5
# Speed: 88.75
# Complex number: (2+3j)
# Complex multiplication: (13+0j)
