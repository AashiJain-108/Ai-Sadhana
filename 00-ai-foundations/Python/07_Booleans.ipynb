# %% [markdown]
# ## <div align="center"><u>**BOOLEANS**</u></div>

# %% [markdown]
# Booleans represent one of two values: True or False.

# %%
x = True
type(x)
# Out:
# bool

# %%
y = False
type(y)
# Out:
# bool

# %%
num1 = 8
num2 = 5
num1>num2
# Out:
# True

# %%
num1<num2
# Out:
# False

# %%
num1==num2
# Out:
# False

# %%
num1!=num2
# Out:
# True
